# %% [markdown]
# <a href="https://colab.research.google.com/github/isaacuchoa/salaryJob/blob/main/sal%C3%A1rio_job.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/data_teste/Salary_Data.csv', delimiter=',')
df.info
# Out:
# <bound method DataFrame.info of        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# ...

# %%
df.head(5)
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %% [markdown]
# # Alterando o título dos campos

# %%
df.rename(columns={
    'Age':'Idade',
    'Gender':'Gênero',
    'Education Level':'Nível de Educação',
    'Job Title':'Título Emprego',
    'Years of Experience':'Experiência',
    'Salary':'Salário'
},inplace=True)

df.head(5)
# Out:
#    Idade  Gênero Nível de Educação     Título Emprego  Experiência   Salário
# 0   32.0    Male        Bachelor's  Software Engineer          5.0   90000.0
# 1   28.0  Female          Master's       Data Analyst          3.0   65000.0
# 2   45.0    Male               PhD     Senior Manager         15.0  150000.0
# 3   36.0  Female        Bachelor's    Sales Associate          7.0   60000.0
# 4   52.0    Male          Master's           Director         20.0  200000.0

# %% [markdown]
# # Verificando Campos nulos

# %%
plt.figure(figsize=(12,4))
plt.title("Verificando campos nulos")
sns.heatmap(df.isnull());

# %% [markdown]
# # Alterar as colunas idade e experiência (Float) para Inteiro, removendo as casas decimais.

# %%
df['Idade'] = df['Idade'].values.astype(np.int64)
df['Experiência'] = df['Experiência'].values.astype(np.int64)
df.head()
# Out:
#    Idade  Gênero Nível de Educação     Título Emprego  Experiência   Salário
# 0     32    Male        Bachelor's  Software Engineer            5   90000.0
# 1     28  Female          Master's       Data Analyst            3   65000.0
# 2     45    Male               PhD     Senior Manager           15  150000.0
# 3     36  Female        Bachelor's    Sales Associate            7   60000.0
# 4     52    Male          Master's           Director           20  200000.0

# %% [markdown]
# #Avaliar salário por Gênero:

# %%
plt.figure(figsize=(10,5))
plt.title("Análise salário x Gênero")
plt.style.use('ggplot')

sns.barplot(data=df, x='Gênero', y='Salário',errorbar=None );

# %% [markdown]
# #Análise de salário por formação

# %%
plt.figure(figsize=(14,5))
plt.title("Análise salário x Nível de educação")

sns.boxplot(data=df, x="Nível de Educação", y="Salário", palette='pastel');

# %%
plt.figure(figsize=(12,5))
plt.title('Análise de experiência por idade')
sns.barplot(data=df, x='Idade', y='Experiência');

# %% [markdown]
# #Análise de idade por gênero:

# %%
plt.figure(figsize=(10,4))
plt.title('Análise de idade por gênero')
sns.boxplot(data=df, x='Gênero', y='Idade', palette='pastel');

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6704 entries, 0 to 6703
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Idade              6704 non-null   int64
#  1   Gênero             6702 non-null   object
#  2   Nível de Educação  6701 non-null   object
#  3   Título Emprego     6702 non-null   object
#  4   Experiência        6704 non-null   int64
#  5   Salário            6699 non-null   float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 314.4+ KB
